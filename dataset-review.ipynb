# %%
import pandas as pd
df = pd.read_csv('careers.csv')
df
# Out:
#                   career                                             skills  \
# 0         Data Scientist         'Python' 'ML' 'Data Analysis' 'Statistics'
# 1            AI Engineer                'Python' 'AI' 'Deep Learning' 'NLP'
# 2          Web Developer                  'HTML' 'CSS' 'JavaScript' 'React'
# 3        Product Manager            'Leadership' 'Planning' 'Communication'
# 4      Software Engineer            'Python' 'Java' 'C++' 'Problem Solving'
# 5       Graphic Designer        'Creativity' 'Photoshop' 'Illustrator' 'UX'
# 6       Business Analyst  'Excel' 'Data Analysis' 'Communication' 'Probl...
# 7  Cybersecurity Analyst  'Networking' 'Security' 'Problem Solving' 'Ris...
#
#                                          description
# 0          Analyze data and build predictive models.
# 1   Develop AI systems to solve real-world problems.
# 2  Build and maintain websites and web applications.
# 3             Lead product development and strategy.
# ...
